# %% [markdown]
# Аттрактор Лоуренса
# работает в 17.12.py

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from scipy.integrate import odeint
import numpy as np
import scipy
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
import random
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib inline
def lorenz(x, y, z, s=10, r=18, b=2.667):
    '''
    Given:
       x, y, z: a point of interest in three dimensional space
       s, r, b: parameters defining the lorenz attractor
    Returns:
       x_dot, y_dot, z_dot: values of the lorenz attractor's partial
           derivatives at the point x, y, z
    '''
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return x_dot, y_dot, z_dot


dt = 0.01
num_steps = 100000

# Need one more for the initial values
xs = np.empty(num_steps + 1)
ys = np.empty(num_steps + 1)
zs = np.empty(num_steps + 1)


# Plot
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')

ax.set_xlim(-15,15)
ax.set_ylim(-15,15)
ax.set_zlim(0,20)

xs[0], ys[0], zs[0] = (0.1, 1., 1.05)
for i in range(num_steps):
    x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
    xs[i + 1] = xs[i] + (x_dot * dt)
    ys[i + 1] = ys[i] + (y_dot * dt)
    zs[i + 1] = zs[i] + (z_dot * dt)
ax.plot(xs.copy(), ys.copy(), zs.copy(), '-k', lw=0.5)

# xs *= 0; ys *= 0; zs *= 0;
# xs[0], ys[0], zs[0] = (-10., 1., 1.05)
# for i in range(num_steps):
#     x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
#     xs[i + 1] = xs[i] + (x_dot * dt)
#     ys[i + 1] = ys[i] + (y_dot * dt)
#     zs[i + 1] = zs[i] + (z_dot * dt)
# ax.plot(xs.copy(), ys.copy(), zs.copy(), '-r', lw=0.5)

ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()



e,h = np.histogramdd(zs,bins=30)  
print(e.shape)
print(h[0].shape)

#строим гистограмму, по одной из

# %matplotlib inline
ax = plt.axes()
ax.plot(h[0][:-1], np.log(e))
# Out:
# C:\Users\DMITRI~1.PUS\AppData\Local\Temp/ipykernel_17872/1956104301.py:28: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# (30,)
# (31,)

# %% [markdown]
# Зупаскаем серию начальных условий

# %%
# %matplotlib inline
def lorenz(x, y, z, s=10, r=18, b=2.667):
    '''
    Given:
       x, y, z: a point of interest in three dimensional space
       s, r, b: parameters defining the lorenz attractor
    Returns:
       x_dot, y_dot, z_dot: values of the lorenz attractor's partial
           derivatives at the point x, y, z
    '''
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return x_dot, y_dot, z_dot


dt = 0.01
num_steps = 1000

# Need one more for the initial values
xs = np.empty(num_steps + 1)
ys = np.empty(num_steps + 1)
zs = np.empty(num_steps + 1)


# Plot
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')

ax.set_xlim(-15,15)
ax.set_ylim(-15,15)
ax.set_zlim(0, 20)

range_min, range_max = (-20,20)
n_his = 10

initialStates=list(zip(
    [random.randint(range_min,range_max) for i in range(n_his)],
    [random.randint(range_min,range_max) for i in range(n_his)],
    [random.randint(range_min,range_max) for i in range(n_his)]
    ))
    
print(initialStates)

xsList = []; ysList = []; zsList = []


for initialState in initialStates:

    xs[0], ys[0], zs[0] = initialState
    for i in range(num_steps):
        x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
        xs[i + 1] = xs[i] + (x_dot * dt)
        ys[i + 1] = ys[i] + (y_dot * dt)
        zs[i + 1] = zs[i] + (z_dot * dt)

        xsList.append(xs[i + 1]); ysList.append(ys[i + 1]); zsList.append(zs[i + 1])



    ax.plot(xs.copy(), ys.copy(), zs.copy(), '-', lw=0.5)


    ax.set_xlabel("X Axis")
    ax.set_ylabel("Y Axis")
    ax.set_zlabel("Z Axis")
    ax.set_title("Lorenz Attractor")



plt.show()
# Out:
# C:\Users\DMITRI~1.PUS\AppData\Local\Temp/ipykernel_17872/1669745259.py:28: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# [(17, -11, 6), (12, 0, 0), (-3, 2, -9), (11, 3, -19), (17, -11, -18), (2, -15, -9), (-12, 11, -7), (-10, -8, -8), (-18, 13, 6), (-3, 3, 6)]

# %%
# print(zsList)
for s in zsList:
  e,h = np.histogramdd(s,bins=20)

  #строим гистограмму, по одной из

  # %matplotlib inline
  ax = plt.axes()
  ax.plot(h[0][:-1], e)
# plt.show()

# %% [markdown]
# С odint от Андрея

# %%
# %matplotlib inline
from scipy.integrate import odeint
def lorenz(x, y, z, s=10, r=25, b=2.667):
    '''
    Given:
       x, y, z: a point of interest in three dimensional space
       s, r, b: parameters defining the lorenz attractor
    Returns:
       x_dot, y_dot, z_dot: values of the lorenz attractor's partial
           derivatives at the point x, y, z
    '''
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return x_dot, y_dot, z_dot
    
L =lambda p,t: lorenz(p[0], p[1],p[2])
x0 = []
xlm = (-20,20)
ylm = (-10,20)
zlm = (2,40)

for i in range(10):
    x0.append ( [ np.random.random()*(xlm[1])-xlm[0]+xlm[0],
                  np.random.random()*(ylm[1])-ylm[0]+ylm[0],
                  np.random.random()*(zlm[1])-zlm[0]+zlm[0] ])

tt=np.arange(0, 100, 0.01)

fig = plt.figure(figsize=(10,10))
plot = fig.add_subplot(111, projection='3d')
# plt.figure(figsize=(10,10)).addsubplot()
zstore = []

for _x0 in x0:
    sol = odeint(L, _x0, tt)
    plot.plot(sol[:,0], sol[:,1], sol[:,2])
    zstore.append(sol[:,2])

# %%
plt.figure(figsize=(10,10))
zstore = np.array(zstore)
zstore.shape

# %matplotlib inline
ax = plt.axes()
for i in range(zstore.shape[0]):
    e,h = np. histogramdd(zstore[i,:], bins = 50)
    ax.plot(h[0][:-1], np.log(e))
plt.show()
